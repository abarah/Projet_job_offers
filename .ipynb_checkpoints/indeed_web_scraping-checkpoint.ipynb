# %%
from selenium import webdriver
import csv
from selenium.webdriver.common.by import By
import time

def main_indeed(keyword, location, InternType):
    # Initialiser le driver de Selenium
    driver = webdriver.Chrome()
    
    # Se rendre sur la page de recherche d'offres d'emploi Indeed
    if InternType == "PFE":
        url = f'https://ma.indeed.com/jobs?q=PFE+{keyword}&l={location}&jt=internship&lang=en'
    elif InternType == "PFA":
        url = f'https://ma.indeed.com/jobs?q=PFA+{keyword}&l={location}&jt=internship&lang=en'
    else:
        url = f'https://ma.indeed.com/jobs?q={keyword}&l={location}&jt=internship&lang=en'
        
    driver.get(url)

    # Attendre 5 secondes pour que tous les éléments soient chargés
    time.sleep(5)

    # Extraire les résultats
    jobs_list = driver.find_elements(By.XPATH, '//div[contains(@class, "job_seen_beacon")]')

    # Écrire les résultats dans un fichier CSV
    with open('indeed_data.csv', mode='w', encoding='utf-8', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Title', 'Company', 'Location', 'Description', 'Link'])

        for job in jobs_list:
            title = job.find_element(By.XPATH, './/a[contains(@class, "jcs-JobTitle")]').text.strip()
            # Vérifier si la liste contenant les éléments de la société n'est pas vide avant d'extraire la chaîne de texte
            company = job.find_elements(By.CSS_SELECTOR, 'span.companyName')
            if company:
                company = company[0].text.strip()
            else:
                company = ""
            description = driver.find_element(By.ID, 'jobDescriptionText').text.strip()
            location = job.find_element(By.XPATH, './/div[contains(@class, "companyLocation")]').text.strip()
            link = job.find_element(By.XPATH, './/a[contains(@class, "jcs-JobTitle")]').get_attribute('href')
            writer.writerow([title, company, location, description, link])
            #print(f'{title} ({company}) - {location}\nLink: {link}\n')

    # Fermer le navigateur
    driver.quit()
# Out:
# Data Entry and Development Operator ( Remote Work ) (Health supply 770) - Casablanca
# Link: https://ma.indeed.com/company/Health-Supply-770/jobs/Data-Entry-Clerk-1e48db70f1e05a0f?fccid=2814ad294fea2e10&vjs=3
#
# Data Analyst (Leyton Maroc) - Casablanca
# Link: https://ma.indeed.com/rc/clk?jk=f9b50f1f820586db&fccid=c18daf68fbd3c338&vjs=3
#
# Data Analyst (Maersk) - Tanger
# Link: https://ma.indeed.com/rc/clk?jk=59c9b806fabd3dfc&fccid=14e7391c55beeb80&vjs=3
#
# Data Scientist (lafargeholcim) - Settat
# Link: https://ma.indeed.com/rc/clk?jk=bb56d63720ce1ff9&fccid=a39549c85aefc9a6&vjs=3
#
# Junior Computer Science / Computer Engineering / Data Engineering Graduates (EDICOM) - Casablanca
# Link: https://ma.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0CcDBaXGkmUwgDfuwqlB9JONLMla20a0J32IoAIcWUOzINMv1m4sKDC6LYXCNFcnoHTmayjGdzl-DscwDqOGQp8fmBNkWmnju6ELHtT-W4MBjZc3LS9d6vxStBioSlQS3bDga-ELCVI_nvoOyVJFGLOopJVrKYWVeReFIncN4UK13wCuykqc74nv7xbxnNLGkax2oziW9Y-Ut5fM0_oqVv1J1a8RKl8c4A0wWihBsWJPnpPBrCgPDp9E1C9byGBdV2nL4MIb2fRmYTImoO-XyTI-QnxV7CPM-xuwmIt6ziEWX5LKxtxb7RHY0_Q6jUT3dQU28Qmh6b8fiaam1V1sRaqdAjE57PrY2FKRaZpcKqwH6WY84-zdCoBv5qBEGDsBQoCELOhcJqczi6HVanuUttochgSFRzFPH3_nuWFkS-LtHI7OjhngoyyU9qGDVM92zSkwC15uMBtPDmxJAOXVW-6HB3sfWnEpeKqoDwGJutrS1WZdzE0jzOh3BhhZDwltXYpKpp8d1F2Va_cQsrWCZ_R7ijCmqGA2YatA-urPaN8rcX4rFfTj1vnyaQ_llWmyV6IumNrCFMy2g==&xkcb=SoBk-_M3PJcbx_SFkh0PbzkdCdPP&p=4&fvj=1&vjs=3
#
# Data analyst intern () - Casablanca
# Link: https://ma.indeed.com/rc/clk?jk=9a33f0a505be69f8&fccid=dd616958bd9ddc12&vjs=3
#
# Data Scientist (Xpertize.MA) - Région de Casablanca-Settat
# Link: https://ma.indeed.com/rc/clk?jk=8afd5cfa35143cc9&fccid=0281e98ef17d6eb9&vjs=3
#
# Engineering internship in Sweden! (Iknal Semikan) - Rabat
# Link: https://ma.indeed.com/rc/clk?jk=82d40bafc023bd55&fccid=1c1f99bc5683e9f2&vjs=3
#
# Junior Finance and Investment Analyst Intern (LixCap) - Casablanca
# Link: https://ma.indeed.com/company/Lixia-Capsia-Gestionis/jobs/Junior-Investment-Analyst-2bb93426ad7e0c35?fccid=652ee52fab9e065d&vjs=3
#
# Research Analyst Intern (LixCap) - Casablanca
# Link: https://ma.indeed.com/company/Lixia-Capsia-Gestionis/jobs/Research-Intern-684a31154652a5ef?fccid=652ee52fab9e065d&vjs=3
#
# Offre: Data entry specialist () - Casablanca
# Link: https://ma.indeed.com/rc/clk?jk=da7569e1368e4c7b&fccid=dd616958bd9ddc12&vjs=3
#
# Junior Tester (Capgemini) - Casablanca
# Link: https://ma.indeed.com/rc/clk?jk=15c26b0c0043263c&fccid=105ecfd0283f415f&vjs=3
#
# Data analyst intern (METAVERSE SARL) - Casablanca
# Link: https://ma.indeed.com/rc/clk?jk=3eaf7e2975b5baf6&fccid=62a1bbbfbd3e41ce&vjs=3
#
# PMO & Data Consolidation Manager (Lean Management consulting) - Casablanca
# Link: https://ma.indeed.com/company/Lean-Management-Consulting/jobs/Consolidations-Manager-b586ad973cb271ab?fccid=cbce3dc1b7566409&vjs=3
#
# Intern (Groupe Kering) - Menara
# Link: https://ma.indeed.com/rc/clk?jk=cc3c87fdc6ac7e55&fccid=2c1ebe710125ee82&vjs=3

# %%
from selenium import webdriver
import csv
from selenium.webdriver.common.by import By
import time

# Initialiser le driver de Selenium
driver = webdriver.Chrome()
# Se rendre sur la page de recherche d'offres d'emploi Indeed
keyword = 'data'
location = 'morocco'
url = f'https://ma.indeed.com/jobs?q={keyword}&l={location}&lang=en'
driver.get(url)

# Attendre 5 secondes pour que tous les éléments soient chargés
time.sleep(5)

# Écrire les résultats dans un fichier CSV
with open('indeed_data.csv', mode='w', encoding='utf-8', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Title', 'Company', 'Location', 'Description', 'Link'])

    for i in range(20): # scrape 8 pages
        # Extraire les résultats
        jobs_list = driver.find_elements(By.XPATH,'//div[contains(@class, "job_seen_beacon")]')
        for job in jobs_list:
            title = job.find_element(By.XPATH,'.//a[contains(@class, "jcs-JobTitle")]').text.strip()
            # Vérifier si la liste contenant les éléments de la société n'est pas vide avant d'extraire la chaîne de texte
            company = job.find_elements(By.CSS_SELECTOR, 'span.companyName')
            if company:
                company = company[0].text.strip()
            else:
                company = ""
            description = driver.find_element(By.ID, 'jobDescriptionText').text.strip()
            location = job.find_element(By.XPATH,'.//div[contains(@class, "companyLocation")]').text.strip()
            link = job.find_element(By.XPATH,'.//a[contains(@class, "jcs-JobTitle")]').get_attribute('href')
            writer.writerow([title, company, location, description, link])
            print(f'{title} ({company}) - {location}\nLink: {link}\n')
        
        # Cliquer sur le bouton "Next"
        try:
            next_button = driver.find_element(By.XPATH, '//a[@aria-label="Next"]')
            next_button.click()
            time.sleep(5)
        except:
            print('No more pages')
            break
# Out:
# Data Entry and Development Operator ( Remote Work ) (Health supply 770) - Casablanca
# Link: https://ma.indeed.com/company/Health-Supply-770/jobs/Data-Entry-Clerk-1e48db70f1e05a0f?fccid=2814ad294fea2e10&vjs=3
#
# Data Analyst (Leyton Maroc) - Casablanca
# Link: https://ma.indeed.com/rc/clk?jk=f9b50f1f820586db&fccid=c18daf68fbd3c338&vjs=3
#
# Data Analyst (Maersk) - Tanger
# Link: https://ma.indeed.com/rc/clk?jk=59c9b806fabd3dfc&fccid=14e7391c55beeb80&vjs=3
#
# Data Scientist (lafargeholcim) - Settat
# Link: https://ma.indeed.com/rc/clk?jk=bb56d63720ce1ff9&fccid=a39549c85aefc9a6&vjs=3
#
# Junior Computer Science / Computer Engineering / Data Engineering Graduates (EDICOM) - Casablanca
# Link: https://ma.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0CcDBaXGkmUwgDfuwqlB9JONLMla20a0J32IoAIcWUOzINMv1m4sKDC6LYXCNFcnoHTmayjGdzl-DscwDqOGQp8fmBNkWmnju6ELHtT-W4MBjZc3LS9d6vxStBioSlQS3bDga-ELCVI_nvoOyVJFGLOopJVrKYWVeReFIncN4UK19W84Hnts29ssWrwS9B-HAxa3HRdOYtlpfkegk6yFbGx_403FLBRdPNoU1w1vnPv4xRZP_SmhnkSs_g6hgXAZgV6t0-GVHJ4E1-RxQahopzvFpb55smOrs-OM8iWUOtTuVxM0K-q9cxK4km5RBrGAsO9_DZ4C106leVB7vFtvbcO0Q24G2OevmNHRjzB5pTGTCBiv7E64RK1_46ltVdp1BWgCL85gKwFTfDHhw9rSSve1sRkA7e1xvUc3M1FFG7HaepQqlFgcSV8HO4ztLIO8ybrck-0r-HqIRoI1NQ9s1izec5uYt6sc996Ox6KlXjoDiawatvsvHlBaumqsgxWEkufxdma9BbGPkVvZKkLkH2epATBSIoZO2w92KJwZigS9fsAOVPMp6L74-P-XGwpR0fuCEeYaecPgw==&xkcb=SoBb-_M3PJdnz1x_jB0PbzkdCdPP&p=4&fvj=1&vjs=3
#
# Data analyst intern () - Casablanca
# Link: https://ma.indeed.com/rc/clk?jk=9a33f0a505be69f8&fccid=dd616958bd9ddc12&vjs=3
#
# Engineering internship in Sweden! (Iknal Semikan) - Rabat
# Link: https://ma.indeed.com/rc/clk?jk=82d40bafc023bd55&fccid=1c1f99bc5683e9f2&vjs=3
#
# Data Scientist (Xpertize.MA) - Région de Casablanca-Settat
# Link: https://ma.indeed.com/rc/clk?jk=8afd5cfa35143cc9&fccid=0281e98ef17d6eb9&vjs=3
#
# Junior Finance and Investment Analyst Intern (LixCap) - Casablanca
# Link: https://ma.indeed.com/company/Lixia-Capsia-Gestionis/jobs/Junior-Investment-Analyst-2bb93426ad7e0c35?fccid=652ee52fab9e065d&vjs=3
#
# Research Analyst Intern (LixCap) - Casablanca
# Link: https://ma.indeed.com/company/Lixia-Capsia-Gestionis/jobs/Research-Intern-684a31154652a5ef?fccid=652ee52fab9e065d&vjs=3
#
# Intern (Groupe Kering) - Menara
# Link: https://ma.indeed.com/rc/clk?jk=cc3c87fdc6ac7e55&fccid=2c1ebe710125ee82&vjs=3
#
# Junior Tester (Capgemini) - Casablanca
# Link: https://ma.indeed.com/rc/clk?jk=15c26b0c0043263c&fccid=105ecfd0283f415f&vjs=3
#
# Offre: Data entry specialist () - Casablanca
# Link: https://ma.indeed.com/rc/clk?jk=da7569e1368e4c7b&fccid=dd616958bd9ddc12&vjs=3
#
# PMO & Data Consolidation Manager (Lean Management consulting) - Casablanca
# Link: https://ma.indeed.com/company/Lean-Management-Consulting/jobs/Consolidations-Manager-b586ad973cb271ab?fccid=cbce3dc1b7566409&vjs=3
#
# Data analyst intern (METAVERSE SARL) - Casablanca
# Link: https://ma.indeed.com/rc/clk?jk=3eaf7e2975b5baf6&fccid=62a1bbbfbd3e41ce&vjs=3
#
# No more pages
