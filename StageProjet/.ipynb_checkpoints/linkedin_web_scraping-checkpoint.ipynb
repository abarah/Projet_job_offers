# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import csv
import time

def main_linkedin(keyword, location, InternType):
    # Initialize the webdriver
    driver = webdriver.Chrome()

    if  InternType == "PFE":
        url = f'https://ma.linkedin.com/jobs/search/?f_E=2&f_TP=1&keywords={keyword}&location={location}'
    elif InternType == "PFA":
        url = f'https://ma.linkedin.com/jobs/search/?f_E=2&f_TP=1&f_JT=2&keywords={keyword}&location={location}'
    else :
        url = f'https://ma.linkedin.com/jobs/search/?f_JT=F&keywords=stage%20{keyword}&location={location}'
    # Navigate to the LinkedIn job search page
   # url = f'https://www.linkedin.com/jobs/search/?keywords={keyword}&location={location}'
    driver.get(url)

    # Wait for the page to load
    time.sleep(5)

    # Initialize a counter for the number of pages scraped
    page_count = 1

    # Loop through the first 4 pages of results
    while page_count <= 4:

        # Get the HTML of the current page
        page_html = driver.page_source

        # Parse the HTML with BeautifulSoup
        soup = BeautifulSoup(page_html, 'html.parser')

        # Find all the job listings on the page
        jobs_list = soup.find_all('div', {'class': 'job-search-card'})

        # Loop through the job listings and extract the relevant data
        for job in jobs_list:
            title = job.h3.text.strip()
            company = job.h4.text.strip()
            location = job.find('span', class_='job-search-card__location').text.strip()
            link = job.a.get('href')

            # Open the job page to get the full job description
            driver.get(link)
            time.sleep(5)
            job_html = driver.page_source
            job_soup = BeautifulSoup(job_html, 'html.parser')
            description = job_soup.find('div', {'class': 'description__text'}).text.strip()

            # Write the data to a CSV file
            with open('linkedin_data.csv', mode='a', encoding='utf-8', newline='') as file:
                writer = csv.writer(file)
                writer.writerow(['Title', 'Company', 'Location', 'Description', 'Link'])

            # Print the job data to the console
            #print(f'{title} ({company}) - {location}\nLink: {link}\nDescription: {description}\n')

        # Click the "Next" button to go to the next page
        try:
            next_button = driver.find_element_by_xpath('//button[@aria-label="Next"]')
            next_button.click()
            page_count += 1
            time.sleep(5)
        except:
            print('No more pages.')
            break

    # Close the webdriver
    driver.quit()
# Out:
# Data Science Intern (CommonShare) - Maroc
# Link: https://ma.linkedin.com/jobs/view/data-science-intern-at-commonshare-3597007652?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=2%2BSecwf3mX6AQZtcxmB4Fw%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: CommonShare is a common protocol and ecosystem for building transparent, sustainable, and resilient supply chains.The RoleYour Responsibilities Will Include﻿Collecting, cleaning, preprocessing, and analyzing data using statistical methods and machine learning techniques.Developing and maintaining scripts and tools to automate data processing and analysis tasks.Creating and maintaining data visualizations to communicate insights and results to stakeholders.Collaborating with data scientists and engineers to design and implement predictive models and algorithms.Participating in data-driven projects and supporting business decision-making processes.Communicating findings and results to technical and non-technical stakeholders.Ideal ProfileSkills RequiredYou are able to communicate, write and speak professionally in English.You are someone who cares deeply about your team so you are both direct and believe in doing what you say.You are passionate about sustainability. You understand that this is the challenge of this generation.You have advanced Knowledge of excel and scraping tools.You have strong data modeling skills.What's on Offer?Work within a company with a solid track record of successPotential to become a full-time employee based on performance.
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Junior Tester (Capgemini) - Casablanca, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/junior-tester-at-capgemini-3598327507?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=H6Ze5pSGLuaagBkcfsa%2FMw%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: About CapgeminiCapgemini is a global leader in partnering with companies to transform and manage their business by harnessing the power of technology. The Group is guided everyday by its purpose of unleashing human energy through technology for an inclusive and sustainable future. It is a responsible and diverse organization of over 360,000 team members in more than 50 countries. With its strong 55-year heritage and deep industry expertise, Capgemini is trusted by its clients to address the entire breadth of their business needs, from strategy and design to operations, fueled by the fast evolving and innovative world of cloud, data, AI, connectivity, software, digital engineering and platforms. The Group reported in 2022 global revenues of €22 billion.Get The Future You Want* | www.capgemini.comCapgemini, le futur que vous voulezYou graduated as an engineer in 2022 and are looking for your first experience in software development ?You are organized, rigorous, responsive, and a team player.You have active listening skills and good interpersonal skills.You have good written and oral communication skills in French and English.You are open-minded You have a customer service mindset.Vous avez décroché votre diplôme d’Ingénieur en 2022 et vous êtes à la recherche d'une première expérience en développement informatique ?Vous êtes organisé(e), rigoureux(se), faisant preuve de réactivité et d'esprit d'équipe,Vous avez une écoute active et un bon relationnel,Vous avez une bonne communication écrite et orale en français et en Anglais,Vous êtes Ouvert d'esprit,Vous avez le sens du service client.Why Capgemini is uniqueCapgemini focuses on giving each new hire a YOU-nique experience through our recruitment process and on-boarding program, as well as by helping you to build your own career and professional skills foundation. The group provides a collaborative environment that embodies and holds the following stated values close to heart: Honesty, Boldness, Trust, Freedom, Team Spirit, Modesty, and Fun.Capgemini cultivates an atmosphere for development that enables YOU to be hands-on, planning for your growth, both horizontally and vertically. This is driven by our digital learning platform ‘Next’ and our ‘Learning for all’ mindset.Join our team - our success is built on your ambitions !
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Retail Business Analyst (Vivo Energy) - Méchouar de Casablanca, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/retail-business-analyst-at-vivo-energy-3596788088?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=s8yhHJc4LVoLkQlKaykz8g%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Job Purpose:Monitor Retail activity on a daily/weekly/monthly basisSupport Sales team for a better tracking & fulfilment of targetsDrive performance analysis for Retail KPIs and share with Retail teamsTransform raw data into exploitable conclusions to help facilitate decision makingGuarantee metrics and Master data accuracy Direct Debit (DD)/PPD Ensuring respect of governance as per MOA recommendations. Principal Accountabilities: Business Analysis Reporting of KPI performance against targets (PMTDR, sales, trade debtor…) Issue periodic reports to track sales, budget expenses, profitability, margins, credit limits and trade debtors’ vs planned objectives. Support S&OP process by providing fuel & lubes forecast Actuals volume reporting (L4L, site performance follow up,…) Support T&R planning exercise by working on Retail targets Fuel Run dries follow up Follow up of lubes stock and daily delivery program Follow up and analysis of daily volume performance Manage retailers’ accounts and assure held orders are unblocked Follow up on Retail trade debtors KPI’s Provide support in terms of retail meeting presentations Prepare the Business Review presentation monthly by updating main performance KPIs and consolidating different qualitative & quantitative inputs from Retail departments Monthly update of Like for Like analysis per Site/Territory/All Retail and complete analysis with Sales team feedbacks. Communicate monthly L4L rate to MI Perform a deep dive analysis for Negative L4L Sites: track the impact of different activations that target these sites and the evolution of their L4L rate Follow up Shining sites’ performance before works vs after works, analyze this performance vs adjacent/ close sites and respective territories PMTDR  Ensuring all Targets and performance data are uploaded into VST Consolidating all data required for the Online RMP· Drive the Performance Improvement Program in collaboration with the Sales Manager & operations support manager Ensure data cleaning in VST Update Retail Site Register and perform quarterly Retail data reconciliation with Internal Controls to ensure database accuracy Clean up & validate Cost Centers list with respective Retail teams Update quarterly GEA database with new sites, closed sites and any occurred changes and share with GBW teamManage the Reward and Recognition Program in collaboration with the Sales Manager & operations support manager Operating PlatformPreparations of the cluster and single site business plans (Yearly and quarterly follow-up)Ensure retailers’ rebates are edited, uploaded into the system and matching between rebates and asset monthly reimbursement is done on a monthly basisSupport the sales team concerning the retailers master planning (retailer competency assessment, Retailer financial assessment)Assure rental income adjustment on a timely mannerClean retailers’ account and assure buy out bonus is paidDrive TM time liberalization through DD/RFT on lubricants and facility accounts with priority given to CO sitesSet retailers payment condition changesAssist with Treasury/MRD… to ensure smooth implementation and avoid on hold accounts (bank transfer done, matching of invoices…)Follow-up the PPD process with SD, CSC and Retail sales team Key Challenges:Full respect of reporting deadline locally and centrallyTimely data update on VSTOpex follow up accordingly to planForecast accuracy vs targetRequirementsPost graduate in Sales/marketing. Preferably 2 years’ experience in retail business (sales, marketing or project management)Financial skillsCommunication skillsTime managementEnglish, analytic skills, and business analysis skills including office tools.
#
#
#         Voir plus
#
#
#
#
#         Voir moins
# Data Intelligence & Research Analyst (CommonShare) - Maroc
# Link: https://ma.linkedin.com/jobs/view/data-intelligence-research-analyst-at-commonshare-3600130580?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=ZgAfUh%2FrM07ErQ7O0FR%2BeA%3D%3D&position=4&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: CommonShare operates a platform for managing supply chain traceability, sustainability, quality, and labor compliance. The leadership team behind CommonShare has decades of experience working in the fields of ESG, sustainability, and impact investing. CommonShare’s advisory board is represented by entrepreneurs, impact investors, and current and former executives from organizations such as the United Nations, LGT, the World Resources Institute, Cerulean Ventures, ISEAL Alliance, and the Soil Association.The RoleAbout The RoleWe are seeking a Data Intelligence & Research Analyst with diverse technical experience who can understand the challenges of integrating data and evidence into international development projects and design solutions. The ideal candidate will have a strong research background, strong writing skills, and be well-versed in international development topics. Additional qualifications include being proactive and accustomed to managing and meeting weekly and monthly deadlines. Meticulous attention to detail and the ability to understand abstract concepts are essential to perform well in this role.Your Responsibilities Will IncludeResearch development interventions in a wide range of topics– from women’s empowerment to environmental sustainability –in order to forward understanding related to how best to reach key development objectives such as reducing poverty or improving education outcomes for children.Create slide decks and present them to clients regarding which interventions are best suited to their projects.Monitor the quality of the output of the data analyst team to ensure accuracy and implement quality controls and remediation activities in the event of low-quality outputDevelop and implement innovative research models aimed at improving development outcomes.Work with the Data Architect and Data Scientist to refine the data strategy and design data frameworks.Direct select research projects depending on the needs of clientsInnovate AI applications to research in collaboration with the data science teamIdeal ProfileRequired QualificationsYou are flexible and open to changing priorities and managing multiple tasks simultaneously within compressed timeframes and across multiple time zones and cultural contexts.You have a strong aptitude to adapt and learn quickly with strategic and creative thinking.You have superior, professional written and verbal communication skills.You have strong attention to detail and the ability to prepare documents for senior leadership review with limited direction.You have extensive knowledge of Python, transformers, and Large Language ModelsYou possess a Master’s Degree in international development or a related fieldYou demonstrate proficiency and experience using Microsoft Office and other products such as Microsoft Word, Excel, and PowerPoint, to produce final products for the client.DesiredExperience with data visualization tools (Power BI, Tableau).Consulting experiencePh.D. in International Development or a related field.Understanding of Artificial Intelligence including Natural Language ProcessingWhat's on Offer?Excellent career development opportunitiesWork alongside & learn from best in class talentFlexible working options
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Data Analyst (Stellantis) - Casablanca, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/data-analyst-at-stellantis-3597031079?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=%2BN0zQ%2BYQRlicjeTi5rObSA%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Dans le cadre des activités de Recherche & Développement, nous recherchons un « Pilote réalisation PFM/ Data Analyst» expérimenté. Afin d'assurer le bon dimensionnement de nos véhicules, nous réalisons des profils de mission (PFM) permettant la caractérisation des sollicitations engendrées par nos clients.Le pilote PFM/Data Analyst a la responsabilité du pilotage et réalisation des profils de mission de son pôle, plus en détail, il aura pour mission :Suivi et pilotage du Groupe de réalisationRecenser et arbitrer les besoins de données à acquérir,Décoder, Convertir et analyser les données,Améliorer la qualité des données en appliquant des méthodes statistiques.Synthétiser les données et les résultats.Présenter/expliquer les résultats des PFMCompétences :Vous avez de bonnes connaissances des prestations de niveau véhicule (hybride et électrique/ Groupe moteur propulseur GMP/Liaison au sol LAS)Bonne connaissance de la Conception véhicule et Architecture FonctionnelleBonnes connaissances en statistique et data scienceBonne connaissance de la méthode AGILEConnaissance en langage de programmation PythonVos principales qualités d'analyse, de synthèse et de capacité d'écoute seront des atouts pour mener à bien ces missions
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Laboratory Technician (AmSpec Group) - Maroc
# Link: https://ma.linkedin.com/jobs/view/laboratory-technician-at-amspec-group-3596678941?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=ZcP48uEQkmnzcOXb7QYLBA%3D%3D&position=6&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Job SummaryThe Laboratory Technician performs laboratory testing and analyses work according operating procedures and may include but is not limited to: LNG, Crude Oil, Gas, Chemicals, Minerals, Bulk loadings of dry cargoes. Equipment maintenance and witnessing may be part of the work scope.Responsibilities:To carry out laboratory tests and analysis as per client’s requirements and/or AmSpec standards in a timely andeffective manner;If required to witness tests and procedures;To provide complete and accurate reports/administration, as directed by the Lab Manager or Lab Supervisor;Compiling daily Statistical Quality Control (SQC) data from all test methods that require an SQC, to ensure thelaboratory is operating efficiently;To carry out all tests and analysis work in strict accordance with applicable procedures for operations and safety. To assist in identifying and correcting any non-conformances with regards to quality, operational or safetymatters; To ensure that all activities are performed in compliance with company Quality manuals, following upaudits and by completing actions on time; Work closely with the Operations team to ensure an effective Quality and Quantity service is provided to thecustomer;Establishing and maintaining internal and external / domestic and international client relationships if applicable;Communicate all significant issues relating to laboratory operations, environmental management and safety.RequirementsDesirable skills/experience/educationBachelor Chemistry, Physics or Process Technology; Minimum of 3 years’ experience in a comparable organization and role, minimum 2 years’ experience within the TIC industry.Additional InformationEssentialsAbility to work well with others & independently, without supervision;Advanced communication and interpersonal skills are essential;Candidates must demonstrate advanced verbal and written communication skills in their native language andEnglish;Proficiency in other languages besides Arabic and French (English) is valuable.Must be able to read, understand and follow work instructions in a safe, accurate and timely manner.Proficient in using several types of computer and planning software (Word, Excel. PowerPoint, Outlook)Ensures full compliance with the company’s Health & Safety, Code of Integrity, and Professional Conduct policies.Other InformationWorking in Shift-systems, meaning that extended and/or irregular hours will be required;Actively promotes good housekeeping and safe use of equipment. This job description should not be construed as an exhaustive statement of essential functions, duties,responsibilities or requirements, but a general description of the job. Nothing contained hereinrestricts the company’s rights to assign, change or reassign duties and responsibilities to this job at anytime. AmSpec is an Equal Opportunity Employer and a drug free environment
#
#
#         Voir plus
#
#
#
#
#         Voir moins
# Data Entry Operator  (Remote) (eStaffing Inc.) - Sahara occidental, Maroc
# Link: https://ma.linkedin.com/jobs/view/data-entry-operator-remote-at-estaffing-inc-3531603779?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=3E2uPslv7msNOVPu8V2tJA%3D%3D&position=7&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Job Tittle- Data Entry Operator (Remote)Job location- RemoteSalary Depending on Candidate ExperienceOpening Required 10 Data entry operator.Fresher can also apply.Enter data into system accurately and efficientlyOrganize and maintain files and recordsPerform other duties as assigned by the supervisor.Compiling, verifying the accuracy, and sorting information to prepare source data for computer entry.Reviewing data for deficiencies or errors, correcting any incompatibilities, and checking output.Required Candidate Profile.GOOD KNOWLEDGE OF COMPUTERMUST HAVE LAPTOP OR SYSTEMMUST HAVE BASIC TYPING SPEEDMUST HAVE TYPING ACCURACYNO WORK PRESSURE & NO TIME BOUNDATIONApply to this position directly to get considered, Your application will be reviewed by assigned recruiter and will connect back to you with in 48 hours .
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Business Analyst (Capgemini) - Casablanca, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/business-analyst-at-capgemini-3598327508?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=nAUaN%2Fs9uZIjneW7HLtCgw%3D%3D&position=8&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: About CapgeminiCapgemini is a global leader in partnering with companies to transform and manage their business by harnessing the power of technology. The Group is guided everyday by its purpose of unleashing human energy through technology for an inclusive and sustainable future. It is a responsible and diverse organization of over 360,000 team members in more than 50 countries. With its strong 55-year heritage and deep industry expertise, Capgemini is trusted by its clients to address the entire breadth of their business needs, from strategy and design to operations, fueled by the fast evolving and innovative world of cloud, data, AI, connectivity, software, digital engineering and platforms. The Group reported in 2022 global revenues of €22 billion.Overview of the roleCapgemini Morocco is looking for a junior business analyst who will be working closely with clients to define their business needs and make sure that all requirements are clearly identified and communicated to the technical team.Job DescriptionYour main duties include:Analyzing our clients' business processes and functional needs.Writing requirement specifications and functional specifications.Facilitating scoping workshops with clients.Ensuring adherence to standards to minimize custom development.Assisting the business owner in defining project objectives.Participating in the selection of appropriate solutions.Participating in the definition of the testing plan.Facilitating a team of users.Participating in the analysis of impacts on the organization and work processes.Supporting change management.Defining user training actions.Vos Missions PrincipalesAnalyser avec nos clients leurs processus métiers et leurs besoins fonctionnels. Rédiger l'expression de besoins et les spécifications fonctionnelles. Animer les ateliers de cadrage avec les clients. S'assurer du respect du standard afin de limiter les développements spécifiques.Assister la maîtrise d’ouvrage notamment dans la définition de l’objectif du projet. Participer à la sélection de solutions adéquates.Participer à la définition du plan de recette. Animer une équipe d’utilisateurs. Participer à l’analyse d’impacts sur l’organisation et les processus de travail. Accompagner la conduite du changement Définir des actions de formation utilisateur.QualificationsCandidate must have :A master’s degree of a major engineering school or an equivalent degree (BAC+5)Expérience in integration projects participation A one year experience minimum in a similar role as a Business Analyst or Functional Consultant. A good understanding of organization/processes/flow management. Knowledge of computer science. Excellent writing skills. A fluent skillset in French and English.Understanding agile processes and tools, particularly ScrumDe formation Bac+5 ou + (Ingénieur, Ecole de Commerce ou équivalent)Vous avez déjà participé à des projets d'intégration Vous justifiez d’une expérience minimum de 2 ans dans une fonction similaire en tant que Business Analyst, Consultant FonctionnelVous avez une bonne culture en organisation / processus / gestion des flux.Vous avez des connaissances en informatique.Excellentes qualités rédactionnellesVous parlez couramment le Français et l'anglais.Why Capgemini is uniqueCapgemini focuses on giving each new hire a YOU-nique experience through our recruitment process and on-boarding program, as well as by helping you to build your own career and professional skills foundation. The group provides a collaborative environment that embodies and holds the following stated values close to heart: Honesty, Boldness, Trust, Freedom, Team Spirit, Modesty, and Fun.Capgemini cultivates an atmosphere for development that enables YOU to be hands-on, planning for your growth, both horizontally and vertically. This is driven by our digital learning platform ‘Next’ and our ‘Learning for all’ mindset.Join our team - our success is built on your ambitions!
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Supply Chain Future Vacancy - Pipeline (Unilever) - Méchouar de Casablanca, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/supply-chain-future-vacancy-pipeline-at-unilever-3513510741?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=7N25P1H7ka%2BAt8DsNCuwJQ%3D%3D&position=9&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Who Is UnileverAt Unilever you are more than your job title, you are part of one of the most successful, purpose-led businesses. Work with brands that are loved around the world, improve the lives of our consumers and the communities around us. We produce world-leading brands including Dove, Tresemme, Axe, and Hellmann’s, alongside trusted local names and innovative-forward thinking brands like Ben & Jerry’s, The Dollar Shave Club and Seventh Generation.Work alongside brilliant and inspiring industry leaders and colleagues. If you want to feel proud of what you do and make others proud too, join us. Get a glimpse into life at Unilever and discover how you can help make a better business, a better world and a better you.Unilever’s ambition is to double the size of our business, whilst reducing our overall environmental impact (including sourcing, consumer use and disposal). We are also committed to doing what we can to improve health, nutrition and hygiene, with a target to help more than a billion people take action to improve their health and well-being, as well as sourcing all our agricultural raw materials sustainably by 2020. All of these goals are itemized in around 60 time-based commitments in our Unilever Sustainable Living Plan.Required Skills And QualificationsMinimum of a bachelor’s degree, preferably Engineering and Logistics Major or any relevant majorStrong academic track record: well-standing GPA (or equivalent)Good analytical skills, willingness to learn and strong aptitude for communication skillsFresh graduates up to 2 years of experienceDemonstrated knowledge of FMCG industry is a plusAbility to work collaboratively within a cross-functional teamAbility to extract critical data and generate actionable insightsStrong business acumenApplication Process Application - Start by completing our simple online application. You can import your details from your LinkedIn profile to speed up the process. Gamification Exercise - After your application, if you meet the basic requirements, we’ll invite you to participate in a series of assessment games that look at different cognitive, emotional, and social traits. This will help us find the best fit for you and you will receive personalized feedback after completing the games. Digital Interview – Upon successful completion of the assessment, you will be invited to participate in a digital interview where you can solve real-world problems using Unilever scenarios. This will give you insight into our company culture and how we do business. The interview is split into two parts – three short hypothetical questions followed by a business case. You can record and complete your video anytime, anywhere. All you need is a computer or mobile device with access to video recording (usually standard in most devices) and a stable internet connection.*Please note that the application processing time will take from 3-4 weeks, we highly appreciate your patience while we’re reviewing each application.Unilever is an organisation committed to equity, inclusion and diversity to drive our business results and create a better future, every day, for our diverse employees, global consumers, partners, and communities. We believe a diverse workforce allows us to match our growth ambitions and drive inclusion across the business. At Unilever we are interested in every individual bringing their ‘Whole Self’ to work and this includes you! Thus if you require any support or access requirements, we encourage you to advise us at the time of your application so that we can support you through your recruitment journey.
#
#
#         Voir plus
#
#
#
#
#         Voir moins
# Consultant Junior Analytics F/H (Deloitte) - Méchouar de Casablanca, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/consultant-junior-analytics-f-h-at-deloitte-3600542702?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=uKwdjCQGM3wWmJWKZe0ddA%3D%3D&position=10&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Poste à pourvoir à partir de septembre 2023.Tous nos postes sont ouverts au télétravail.Rejoindre Deloitte, c'est dire oui à une expérience qui a du sens, celle où les rencontres et les missions vous poussent à grandir chaque jour. C’est évoluer dans un environnement de travail fondé sur la confiance, la transmission et l’intelligence collective pour construire l’avenir de nos clients. Un avenir que nous voulons plus responsable, plus durable et respectueux de l’environnement en prenant des initiatives concrètes à notre échelle. Nous rejoindre, c’est aussi dire oui à une entreprise Great Place to Work, attachée au bien-être, et à l’inclusion sans distinction de nos collaborateurs.Et vous, prêts à dire #ISayYes à votre futur chez Deloitte ?Vous souhaitez évoluer au sein d’un des leaders mondiaux, acteur de référence, en Audit, Conseil, Financial Advisory, Risk Advisory et Juridique & Fiscal ? Rejoignez-nous !L’activité Financial Advisory de Deloitte France accompagne ses clients, composés de grands groupes et de fonds d’investissement, en France ou à l’international, depuis la définition de leur stratégie M&A jusqu’à l’exécution post-transaction, dans le but de créer une valeur durable pour l’organisation.Au sein de notre activité Financial Advisory, les missions traitées par nos équipes Economic Advisory et Forensic nécessitent de mobiliser les meilleures techniques de data science pour développer des solutions innovantes au service de nos clients.Le département Economic Advisory regroupe une solide équipe d'économistes et de data scientists qui développent des solutions au service des stratégies d'entreprises : prédiction du niveau des ventes, optimisation du pricing, benchmark de la performance commerciale, stratégie d'implantation de magasins, modélisation du fonctionnement concurrentiel des marchés, etc.Quel sera votre rôle dans la #TeamDeloitte ?Tout en étant basé(e) à Casablanca, vous intégrerez nos équipes françaises et interviendrez en tant qu’expert(e)-développeur(se) en R et en interfaces Shiny. Dans Ce Contexte, Vous Serez Amené(e) à Participer à l'encadrement technique des projets réalisés sous R et des interfaces Shiny en étant force de proposition de solutions innovantes basées sur les évolutions les plus récentes des packages disponibles ;Développer de nouvelles solutions (packages, interfaces de visualisation, etc.) pour répondre aux problématiques business comme aux besoins récurrents de traitement, d'analyse des données, d'automatisation et d'optimisation des process de l'équipe ;Utiliser les outils et techniques d'analyse quantitative de données, des statistiques et de l'économétrie appliquées aux problématiques de l'entreprise ;Extraire, traiter et rassembler l'ensemble des sources de données nécessaires pour les différentes analyses quantitatives ;Concevoir et déployer des interfaces de visualisation qui facilitent la compréhension du fonctionnement des marchés et des stratégies d'entreprises ;Participer à la conception et à l'animation du programme de formation des équipes sur les compétences de data science ;Élargir vos horizons professionnels en travaillant en France et à l'étranger au sein d'équipes pluridisciplinaires réunissant des spécialistes en provenance de nombreux pays. Votre Parcours En rejoignant Deloitte, vous aurez l'opportunité de développer un set de compétences, partagées avec notre réseau international, et structurées autour des dimensions suivantes : leadership, métier et spécialité. Grâce aux missions variées auxquelles vous participerez et au programme de formations proposé, vous pourrez renforcer progressivement ces compétences, en acquérir de nouvelles et progresser ainsi au sein de notre firme.Et si c’était vous ?Diplômé(e) d'une grande école d'ingénieur ou d'un 3ème cycle universitaire avec une spécialisation en data science, en informatique ou dans tout domaine connexe, vous possédez des bases théoriques en systèmes d'exploitation (Unix, Windows), systèmes de fichie ...
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Data Strategist (CIH BANK) - Casablanca, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/data-strategist-at-cih-bank-3590427942?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=sF24NLxEjkC6tWldCkU4Xw%3D%3D&position=11&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Contexte du recrutement et définition de posteRattaché à la Direction Stratégie et Incubation, vous aurez comme mission d'assurer le le brainstorming et l'analyse des uses cases, vous serez le product owner des produits de la Direction et veillerai à ce que les développements réalisés suivent les besoins de connaissance client.Responsabilités principales1- Garantir que les problématiques métiers sont bien traitées S'assurer que chaque besoin métier a bien été pris en compte et est étudié d'un point de vue technologique et data Assurer le suivi de la réponse à la problématique Assurer un retour régulier aux directions métier2- Proposer de nouvelles idées aux directions métier Traduire la donnée disponible et les capacités de développement de produits data en des termes métiers3- Exprimer les besoins métier dans un jargon technique Bien comprendre les techniques et méthodes utilisées dans la Direction Savoir évaluer la complexité d'un use case métier4- Prioriser les besoins au regard de l'intérêt business et de la complexité métier Avoir un rôle de product owner sur les produits Garder en tête l'intérêt du métier5- Présentation des résultats de la DirectionProfil recherchéFormation: Bac+5 école d'ingénieurExpérience requise: 5 ans
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# FrontEnd Intern (CommonShare) - Maroc
# Link: https://ma.linkedin.com/jobs/view/frontend-intern-at-commonshare-3597012269?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=QHuccIHoBK4vaRRHf6Oy5Q%3D%3D&position=12&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: CommonShare is building a common protocol for creating resilient, transparent, digital supply chains.The RoleYour Responsibilities Will IncludeCollecting, cleaning, preprocessing, and analyzing data using statistical methods and machine learning techniques.Developing and maintaining scripts and tools to automate data processing and analysis tasks.Creating and maintaining data visualizations to communicate insights and results to stakeholders.Collaborating with data scientists and engineers to design and implement predictive models and algorithms.Participating in data-driven projects and supporting business decision-making processes.Communicating findings and results to technical and non-technical stakeholders.Working closely with QA engineers to reproduce and validate defectsParticipating in team meetings and providing feedback on product qualityIdeal ProfileSkills RequiredFluent in English in order to be able to effectively liaise with stakeholders in the region.You are someone who cares deeply about your team so you are both direct and believe in doing what you say.You are passionate about sustainability. You understand that this is the challenge of this generation.You have to assist in the creation of test plans and test casesYou have to execute test cases and report defects.What's on Offer?Opportunity to make a positive impactFlexible working optionsPotential to become a full-time employee based on performance.
#
#
#         Voir plus
#
#
#
#
#         Voir moins
# Manager AI & Data Analytics (Capgemini) - Casablanca, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/manager-ai-data-analytics-at-capgemini-3592858924?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=eP5S8dsos%2F4RP4XGmkfg9g%3D%3D&position=13&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Short DescriptionRattaché(e) au Head Of Operations, vous serez en management d’une équipe, en assurant une satisfaction client et une cohésion d’équipe suivant les valeurs de Capgemini Engineering.QualificationsCompétences avancées en statistiques et mathématiques.Connaissance des langages de programmation (SQL, Python, R, VBA, etc.).Connaissances des instruments de Business intelligence.Connaissances en machine learning,AI, Data mining , Cloud AWS & AzureGestion projetManagement de proximitéPower skillsResult & Solution-orientedAnimation Interne & ExterneAnalyse qualité, esprit de synthèse et rigueurSens d’engagement et responsabilitéAvoir un bon niveau en anglais (courant : écrit et oral)CommunicationLeadershipJob Responsibilities Contribuer au recrutement, au « staffing » des projets et à la gestion des inter-contrats. Assurer le management opérationnel et hiérarchique des Consultants tout en veillant à la fidélisation des ressources et leur montée en compétence. Être en charge du management et de la gestion de carrière de ses équipes : (entretiens annuels, augmentations, formation et mobilité, animation des comités carrière…etc.) Être garant des processus Conception de Capgemini Engineering excellence, assurer la promotion / déploiement de la politique d’entreprise. Assurer une gestion optimale de l’allocation des ressources. Assurer la sélection et la validation des profils lors des opérations de staffing de l’équipe. Piloter au quotidien l’avancement des projets, assure le suivi des actions, des livrables et du plan de charge. Animer les différents comités techniques avec l’appui du Project Leader. Analyser les risques et propose les plans d’actions avec le Project Leader ; Participer à la coordination et la relation entre le projet et le management Capgemini Engineering. Réaliser le kit d’intégration et assure la gestion des compétences. Assurer le suivi, la mise à jour, la formation interne, la capitalisation et l’enrichissement du référentiel. Participer à la préparation des appels d’offre et démarrage du nouveau business Proposer des nouveaux chantiers transverses pour mettre en valeur les talents des équipes
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Data Analyst Ref. 003924 (Novancy One | Recrutement de Talents du Digital) - Maroc
# Link: https://ma.linkedin.com/jobs/view/data-analyst-ref-003924-at-novancy-one-%C2%A0recrutement-de-talents-du-digital-3594450061?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=GzkFyqKN3fwVnPGdwdsCUg%3D%3D&position=14&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Missions :Réaliser les tableaux de bord de projets pour le risk management.Assurer la collecte, analyser, et interpréter des data sets pour créer des visuels portant de l’information et des insights pour l’aide à la décision.Travailler en étroite collaboration avec les autres entités et départements pour identifier les besoins métier/business.Designer les data models.Développer et maintenir les tableaux de bord en utilisant TABLEAU, DATAIKU et PostgreSQL pour le data processing et analyse.Profil recherché :Master en computer science, statistiques, mathématiques ou équivalent3+ ans d’expérience en data analyse, développement de dashboards et DataViz
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# JUNIOR DATA SCIENTIST - Dubai, UAE (Cobblestone Energy) - Casablanca, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/junior-data-scientist-dubai-uae-at-cobblestone-energy-3580815705?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=UltydDLmGcRiWe%2BhUdavEg%3D%3D&position=15&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Location: Dubai, UAE (We provide visa sponsorship & relocation assistance)Starting salary of USD 60,000 per annum + performance based bonus - 0% tax environment + an opportunity to join our employee share schemeAbout Cobblestone EnergyCobblestone Energy is an energy trading company specialising in the Great Britain and European wholesale electricity markets. Founded in 2017, we are part of the next generation of companies defining the future of global commodity trading.We make use of advanced data analytics and extensive research to drive profitable decision making, trading enough electricity every day to power a small country, and growing every day. In doing so, we help to balance the electricity grid, lowering the cost to end consumers, and aiding the transition to a renewable future. Technology and risk management form the backbone of our business.At Cobblestone Energy, we are a diverse team of over 50 people from 20+ nationalities - we believe in hiring extraordinary talent from all around the world. Our flat organizational structure helps us in giving our team members complete ownership of the work and ensures ideas come from every level. We believe in providing unlimited growth opportunities to our people alongside constant feedback and support, which allows us to cover our vulnerabilities and grow as a team in new and interesting ways. With the right performance and potential, you could be managing the power desk for an entire country within eighteen months in your role. Come join our dream team!Cobblestone ValuesLifelong learning with continuous reflectionIndependent thinking through a meritocracy of ideasThe team is more important than the individual. Being the best in any market we enterHiring and keeping only the most effective peopleOthers must benefit from our existence. What We Offer In This RoleA full-time position on our Commercial teamCommitted and remarkably talented colleagues. Highly competitive compensation dependent on performanceAn exciting, challenging and fulfilling career. Investment in your development to ensure that you always remain the best in business. Equity participation for strong contributors, ensuring our interests are all aligned long term. Do you have a passion for data and a solid foundation in mathematics and computer science? If you are a recent graduate or early career professional, Cobblestone Energy, a high-speed energy trading company in Dubai, is looking for you to join us as a Junior Data Scientist. Help drive informed decision making throughout the organization.As a Junior Data Scientist at Cobblestone Energy, you will play a critical role in supporting our energy trading operations. You will be responsible for collecting, cleaning, analysing, and interpreting large datasets to uncover trends, patterns, and insights that will drive our business decisions. You will also have the opportunity to develop predictive models to forecast energy prices and trends and collaborate with cross-functional teams to implement data-driven solutions.Key Responsibilities:Developing deep understanding of the industry and delivering key insights by analysing dataForecasting different fundamentals such as wind power generation and demandResearching and implementing new trading strategiesBuilding and developing new or existing data infrastructureYour background:Bachelor's or master's degree in Computer Science, Mathematics, Statistics, or a related fieldStrong proficiency in programming languages such as Python and RExperience with data analysis and manipulation tools such as Pandas, NumPy, and SQLKnowledge of data visualization tools such as Matplotlib and SeabornExperience that demonstrates your team-oriented, innovative, and strategic working styles. Pro-active and flexible work mentalityInterest in data-driven tradingFluency in English, both written and spoken. About the Role: This is an exciting opportunity for a Junior Data Scientist to join a growing and innovative energy trading co ...
#
#
#         Voir plus
#
#
#
#
#         Voir moins
# Senior Data Scientist (H/F) (Attijariwafa bank) - Casablanca et périphérie
# Link: https://ma.linkedin.com/jobs/view/senior-data-scientist-h-f-at-attijariwafa-bank-3604191123?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=k8Kk6m7dw6%2FXv8btyP7ylg%3D%3D&position=16&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Rattaché(e) à notre Data Office, en tant que Senior Data Scientist vous serez en charge de créer et développer des modèles analytics au service des use cases data.A ce titre, vos principales missions seront les suivantes :- Modéliser, mettre en place, animer la solution analytique de la banque tout en garantissant la méthodologique et technique desmodèles de data science développés;- Piloter les use cases data qui contiennent une composante analytique avec toutes les parties prenantes;- Réaliser un suivi statistique précis de la performance des modèles et assister à la gouvernance des modèles déployés et encadrerstatistiquement et méthodologiquement les Data Scientists dans la réalisation de leur tâche;- Organiser et animer des ateliers autour des ouvertures de la data science dans le monde bancaire;- Construire des modèles Machine learning & Intelligence Artificielle : collecter la data, développer et entrainer le modèle, tester et évaluer les résultats;- Optimiser l'exploitation de la donnée;- Innover en terme d'approche analytics à travers de la veille, de nouveaux outils et de nouvelles modélisations. Profil recherché :De formation Ingénieur ou Grande Ecole de Commerce en Statistique / Informatique ou Mathématiques appliquées aux statistiques, vous justifiez d'une expérience confirmée entre 5 et 10 ans idéalement dans le secteur bancaire.Vous possédez, outre des qualités d'analyse et de rédaction, un sens aigu des relations humaines qui vous permettra d’évoluer dans une structure en pleine croissance.Votre culture financière et votre bonne connaissance de l'organisation de la banque seront vos principaux atouts
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Solution Assessment Consultant (ApeironSumus) - Maroc
# Link: https://ma.linkedin.com/jobs/view/solution-assessment-consultant-at-apeironsumus-3593926044?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=LABcmgbxMhsT8vT1xU8g5Q%3D%3D&position=17&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Apeiron Sumus is looking for a Solution Assessment Consultant, who is fluent in English, to join our team serving our Microsoft technology services based in Morocco.The ideal candidate is someone with high energy, a curiosity about the industry, and tenacity and has previous Microsoft Technology sales experience. This person will bring new ideas, think outside the box, have a deep passion for the role and create ways to attain new accounts.This a remote (work from home) position. Responsibilities: Generate lead flow: Engage the account and prepare them for a Solution Assessment. Connect with as many leads as possible to encourage the assessment execution. Be the point person for assessment lead qualification process.Orchestrate Assessment process: Manage and execute the activities required to perform a Solution Assessment in each account.Manage current accounts: Stay in close contact with existing accounts or leads and create brand awareness regarding Solution Assessments. Coordinate remote meetings and calls between the leads, and extended Sales Team.Assessment support: Answer calls and emails from clients, identify opportunities and make suggestions for future or new assessments. Requirements: Bachelors degreeHands-on experience with multiple sales techniquesExperience with Microsoft Office and CRM softwareFamiliarity with MS Excel and PowerBIUnderstanding of sales performance metricsStrong written and verbal communication skillsStrong attention to detail, data analysis, and analytical skillsA desire to integrate consulting on Microsoft solutions and offerings in support of organizations’ business needs, with a technical skillset – working with IT systems and leveraging tools in support of collecting dataSelf-Direction and a focus on quality, with the ability to apply independent judgment to accomplish objectivesAdditional desirable experience that will add value to the role and team include: Project Management, Azure Fundamentals and/or Microsoft Fundamentals certifications, Microsoft licensingAbout Apeiron Sumus:Apeiron Sumus is a global Microsoft Partner dedicated to provide specialized services for cloud adoption and transformation.Powered by JazzHRsb6ZXOY4v3
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Business Analyst_Data Factory Freelance / CDI (CAPFI) - Casablanca, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/business-analyst-data-factory-freelance-cdi-at-capfi-groupe-3555270783?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=DRQsyHmAy%2FRh9uXsmLDaeQ%3D%3D&position=18&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Business Analyst Data FactoryDans le cadre de nos recrutements , nous sommes à la recherche pour l'un de nos clients banacire d'un Business Analyst Data Factory.Expérience requise de 5 ans et plusDisponibilité : Immédiate à AsapMobilité : CasablancaJe vous invite en cas d'intérêt à partager avec moi votre CV sur nora.berrady@capfi.fr
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Business Research - Research Intern - Casablanca (Infomineo) - arrondissement d'Anfa, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/business-research-research-intern-casablanca-at-infomineo-3596566877?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=jINnFwV0mBfB6bN8pTtnLA%3D%3D&position=19&pageNum=0&trk=public_jobs_jserp-result_search-card
# ...
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Business Research - Research Manager - Casablanca (Infomineo) - Méchouar de Casablanca, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/business-research-research-manager-casablanca-at-infomineo-3586047477?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=SYoSD3yn3CcmMX86Jxds7w%3D%3D&position=21&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: About This RoleAre you intellectually curious? Do you have a knack for solving puzzles? Do you want to make an impact? If yes, this role is right for you. As a Business Research Manager at Infomineo, you'll be responsible for performing research, answering clients’ requests and lead a team of analysts in business and investment research needs across different regions and industries.What You Will DoPerform research, answer client requests and autonomously lead a team of analysts and associates in business and investment researchBeing involved in company BD processes, notably through drafting proposals Train, lead and coach a team, clarifying each team member's responsibilities and setting up clear processes Be the primary contact for our clients, perform QA and set up QA processes for the team ensuring that requests are verified, reliable and up to the very high client standardsManage projects, setting priorities and budget time for each componentManage a team, clarify objectives, timeline, and responsibilities Act as professional development coach, by providing coaching, training and development career path for the teamEnsure a high level of motivation within the team to deliver excellenceRequirementsWho you areHave a Master degree and a minimum of 5 years of relevant work experienceHave experience in Strategy ConsultingHave at least 1 managerial experienceExtensive secondary research experience covering the MENA RegionHave the ability to step back, analyze problems, find solutions and implement theseCreative and resourceful, with an ability to find information using different toolsExcellent management skills with a track record of coordinating workflow and assuring quality for large teams with a strong ability to multitaskFull proficiency in English and either French or German, Arabic is a real plusHave expertise with research databases BenefitsWhat we offerA competitive package A great working environment A steep learning curve with interesting and diverse topics to work onA healthy work-life balanceHealth insurance BenefitsWhat is means to work at Infomineo?If you've spoken with someone who works at Infomineo, you've probably heard that our people are our most valuable asset. Their diversity, both in terms of professional experience and culture, is the company’s greatest strengthBy being a part of Infomineo, you'll have the opportunity to work and coach alongside a friendly, smart, and international team that value intellectual vitality and creativity. You'll support leading international institutions & companies with the information and insights they need to fuel their key business decisions. As a member of the team, you'll be encouraged to contribute your ideas and play an instrumental part in the company’s development and growth. Within this role, you will support leading international institutions & companies with the data and information they need to fuel their key business decisions.Equal opportunity employerInfomineo is an equal opportunity employer, we prohibit any sort of discrimination (based on color, race, sex, sexual orientation, religion, national origin or any other attributes) in all aspects of employment (recruiting, hiring, wages and salary, promotions, benefits, trainings and job termination).
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# PROJECT MANAGER (AKWEL) - El Jadida, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/project-manager-at-akwel-3577894279?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=dC46upAoRvSiSduJF8TZRg%3D%3D&position=22&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Main Responsibilities And DutiesManages the budget, the project timing plan and pursues the quality plan, according to development standards and customer requirements.Elaborates and organizes technical meetings and project reviews, in conjunction with his/her team, customers and suppliers’ contact.Manages the project team; coordinate, organize and manage all project activities.Draws up the requests for consultations and purchases, takes an active part in « sourcing committees ».In the event of disagreement, he/she notifies and refers the matter to arbitration by the Product Line Department and the relevant functional department; an appeal is conceived following the agreement of the Product Development Department.Entrusted with the presentation of the design and initial sample files. Monitors their progress until their acceptance by the customer, while relying on the support of Quality teams.Draws on the available IT systems and resources (PDM, EDM project, SAP …) and ensures the reliability of relevant data.Submits the score card (QCD) of the project to the Project Steering Committee (CPP) and the related actions, if required.May have to supervise the activity of one or several Project Manager(s) depending on the organizational structure.Satisfy, with the project team, the customer requirements in compliance with the AKWEL requirements. Requirements :College/University degree of Technical Engineering, strengthened by 3-year’s experience within the industrial field in Research and Process Engineering or A-Level (High School Diploma) + minimum 2-years higher education, reinforced by 3-years related experience.Professional abilitiesOrganizational skills, leading multi-disciplinary and multi-cultural teams, decision making power, synthetic thinking, rigor, interpersonal skills, strong sense of confidentiality ;Command of office automation systems and MS Office (Portal, Word, Excel, PowerPoint…) ;Command of English (required).Localization: ELJADIDA, MOROCCOContract type: Permanent CDIDepartment : Product line and projectStarting date: As soon as possibleIf you are interested in this role and believe that you meet the requirements, please forward your CV and cover letter at: hr.elj@akwel-automotive.comPlease not that incomplete application will not be taken into account.
#
#
#         Voir plus
#
#
#
#
#         Voir moins
# Business Research - Research Team Lead / Junior Manager - Casablanca (Infomineo) - arrondissement d'Anfa, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/business-research-research-team-lead-junior-manager-casablanca-at-infomineo-3590327826?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=nHR1T1wtkyZofnhOYs%2FbKw%3D%3D&position=23&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: About UsInfomineo is a Brainshoring services company, supporting global clients from various geographies and industries across a range of services: Business Research, Business Translation, Graphic Design and Data Analytics.Infomineo counts 250+ employees spread across different offices in the EMEA region and the America’s. Our clients include leading Consultancies, Fortune 500 companies, Governments and NGOs.About This RoleAre you intellectually curious? Do you have a knack for solving puzzles? Do you want to make an impact? If yes, this role is right for you. As a Business Research Team Lead at Infomineo, you'll be responsible for performing research, answering clients’ requests and leading a team of analysts in business and investment research needs across different regions and industries.What You Will DoPerform research, answer client requests and autonomously lead a team of analysts and associates in business and investment researchTrain, lead and coach a team, clarifying each team member's responsibilities and setting up clear processes Be the primary contact for our clients, perform QA and set up QA processes for the team ensuring that requests are verified, reliable and up to the very high client standardsLead and manage different clients, projects and or teams simultaneously, and setting priorities and budget time for each componentManage a team, clarify objectives, timeline, and responsibilities Act as professional development coach, by providing coaching, training, constructive feedback, and development career path for the teamCollaborate with the Professional Development team to create and deliver quality training (onboarding and ongoing training)Ensure a high level of motivation within the team to deliver excellenceSupport with the screening selections for the right candidates. Support to drive different initiatives important to the companyWho You AreHave a master’s degree and a minimum of 4 years of relevant work experienceHave some team management experienceExtensive secondary research experience covering the MENA RegionAble to step back, analyze problems, find solutions, and implement theseCreative and resourceful, with an ability to find information using different toolsGood interpersonal skills and organizational skills, high motivation, an attention to detail, flexibility, and ability to cope under stress, a focus on identifying the solutions to problems Good management skills with a track record of coordinating workflow and assuring quality for small to medium teams with a strong ability to multitaskFull proficiency in English and French. Any additional language is a real plusHave expertise with research databasesWhat We OfferA competitive local salaryHealth insurance BenefitsA healthy work-life balanceA steep learning curve with interesting and diverse topics to work onA great working environmentDon’t hesitate. Apply by clicking on the button. Kindly include a cover letter with your application. We want to learn more about you!Equal opportunity employerInfomineo is an equal opportunity employer, we prohibit any sort of discrimination (based on color, race, sex, sexual orientation, religion, national origin or any other attributes) in all aspects of employment (recruiting, hiring, wages and salary, promotions, benefits, trainings and job termination).If you believe you match our requirements and values, we would be happy to hear from you. Visit our website to know more about us, our services and company culture.What is it like to work at Infomineo?If you've spoken with someone who works at Infomineo, you've probably heard that our people are our most valuable asset. Our diversity, both in terms of professional experience and culture, is the company’s greatest strength.By being a part of Infomineo, you'll have the opportunity to work alongside a friendly, smart, and international team of researchers that value intellectual vitality and creativity. You will learn the best practices, tools to use w ...
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Datascientist (CIH BANK) - Casablanca, Casablanca-Settat, Maroc
# Link: https://ma.linkedin.com/jobs/view/datascientist-at-cih-bank-3590427945?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=79%2F3faC1%2FzsbxPoi0nugsQ%3D%3D&position=24&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: Contexte du recrutement et définition de posteRattaché à la Direction Stratégie et Incubation, le Datascientist a pour mission d'analyser et de valoriser la donnée entrante, tout en gardant un œil métier/technique sur le fonctionnement et l'architecture du Datalab.Résponsabilités Permanentes 1- Garantir une qualité de code exemplaire:  Respecter les règles de code, les conventions stylistiques ainsi que les consignes données Etre critique par rapport aux règles et force de proposition à ce niveau2- Garantir une automatisation poussée des traitements développés: Préparer l'intégration des développements dans les workflows existants Réaliser une automatisation avec configuration possible3- Assurer un niveau confortable de documentation couvrant les aspects techniques et fonctionnels: Documenter largement toutes les parties critiques du code Documenter les workflows globaux Documenter la signification et l'utilisation de donnée4- Tester régulièrement la qualité des données: Effectuer une évaluation préliminaire des données avant leur utilisation Représenter la fiabilité par des dashboards récapitulatifs Se renseigner sur la cause des non fiabilités et les communiquer5- Garantir une cohérence statistique des analyses effectuées Valider régulièrement le workflow d'exécution Vérifier régulièrement l'application de la méthodologie Confronter les résultats obtenus avec les métiers concernés6- Produire des visualisations de données illustrant les analyses effectuées Réaliser des dashboards de data visualisation en concert avec les métiers7- Effectuer une veille technologique et méthodologique régulière sur les sujets de la data scienceConsacrer une demi-journée par semaine au parcours de sujets d'actualité et de nouvelles techniques en fonction des contraintes opérationnelles courantes8- Animer des brainstorming autour de uses cases Tenir des réunions avec les métiers Présenter des cas d'utilisation aux métiersProfil recherchéFormation:  Bac+5 Ecole d'ingénieurSpécialité:  Statistiques / InformatiqueExpérience requise: 3 ans minimum
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# Business Analyst (Confidential) - Casablanca et périphérie
# Link: https://ma.linkedin.com/jobs/view/business-analyst-at-confidential-3605702083?refId=%2B65pHDjPweq3dkh5v0CCyg%3D%3D&trackingId=ZTU2oOp3xyeonXWOuDN0Ug%3D%3D&position=25&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description: I am currently hiring a skilled Business Analyst with a minimum 1 year of experience to join one of my client's team. The successful candidate will be responsible for analyzing business processes and identifying areas for improvement. Would work closely with cross-functional teams to develop and implement solutions to enhance business efficiency and drive growth. ResponsibilitiesAnalyze and document current business processes to identify areas for improvement.Develop and implement business solutions to improve efficiency, profitability, and customer satisfaction.Conduct research and analysis to provide insights into market trends and customer needs.Prepare and present reports on business performance to senior management.Continuously monitor and evaluate business performance and make recommendations for process improvements.Maintain a competitive market knowledgeQualificationsBachelor's degree in Business Administration, Finance, Economics, or a related field.Minimum of 1 year of experience as a Business Analyst.Strong analytical and problem-solving skills.Excellent communication and interpersonal skills.Ability to work independently and collaboratively in a team environment.Experience with data analysis and visualization tools (e.g. Excel, Power BI, Tableau, etc.).Knowledge of project management methodologies (e.g. Agile, Waterfall, etc.).
#
#
#         Voir plus
#
#
#
#
#         Voir moins
#
# No more pages.
